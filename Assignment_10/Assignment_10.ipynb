# %% [markdown]
# ### Portfolio assignment 10
# 15 min: Perform a bivariate analysis (Pearson correlation and scatter plot) on at least 1 combination of 2 columns with numeric data in the dataset that you chose in portfolio assignment 4. Does the correlation and scatter plot match your expectations? Add your answer to your notebook. Commit the Notebook to your portfolio when you're finished.

# %%
import pandas as pd

# %%
Pokemon = pd.read_csv("Pokemon.csv", sep=";")

# %%
Pokemon.head()
# Out:
#                                            abilities  attack  capture_rate  \
# 0  ['Rock Head', 'Sturdy', 'Sand Veil', 'Magnet P...      80         255.0
# 1  ['Stench', 'Sticky Hold', 'Poison Touch', 'Poi...      80         190.0
# 2  ['Rock Head', 'Sturdy', 'Sand Veil', 'Magnet P...      95         120.0
# 3  ['Sand Veil', 'Sand Rush', 'Snow Cloak', 'Slus...      75         255.0
# 4     ['Chlorophyll', 'Harvest', 'Frisk', 'Harvest']     105          45.0
#
#      classfication  defense  experience_growth  height_m  hp       name  \
# 0     Rock Pokémon      100            1059860         0  40    Geodude
# 1   Sludge Pokémon       50            1000000         0  80     Grimer
# 2     Rock Pokémon      115            1059860         0  55   Graveler
# 3    Mouse Pokémon       90            1000000         0  50  Sandshrew
# 4  Coconut Pokémon       85            1250000         0  95  Exeggutor
#
#    percentage_male  pokedex_number  sp_attack  sp_defense  speed   type1  \
# ...

# %%
pokemonCorrelations = Pokemon.corr()
pokemonCorrelations.style.background_gradient(cmap='coolwarm', axis=None).format(precision=2)
# Out:
# <style type="text/css">
# #T_ee94c_row0_col0, #T_ee94c_row1_col1, #T_ee94c_row2_col2, #T_ee94c_row3_col3, #T_ee94c_row4_col4, #T_ee94c_row5_col5, #T_ee94c_row6_col6, #T_ee94c_row7_col7, #T_ee94c_row8_col8, #T_ee94c_row9_col9, #T_ee94c_row10_col10, #T_ee94c_row11_col11, #T_ee94c_row12_col12, #T_ee94c_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ee94c_row0_col1, #T_ee94c_row1_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_ee94c_row0_col2, #T_ee94c_row2_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_ee94c_row0_col3, #T_ee94c_row2_col5, #T_ee94c_row2_col8, #T_ee94c_row3_col0, #T_ee94c_row5_col2, #T_ee94c_row8_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_ee94c_row0_col4, #T_ee94c_row0_col5, #T_ee94c_row4_col0, #T_ee94c_row5_col0, #T_ee94c_row8_col13, #T_ee94c_row13_col8 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_ee94c_row0_col6, #T_ee94c_row6_col0 {
#   background-color: #b1cbfc;
# ...

# %% [markdown]
# De statistiek Special Defense (Sp. Def) bepaalt hoe goed een Pokémon zich kan verdedigen tegen speciale bewegingen. Als de normale Defense statestiek hoog is zal de Defense statestiek tegen speciale aanvallen ook hoog zijn. Ik verwacht dat hier een goede correlatie in te zien is.

# %%
Pokemon.plot(kind='scatter', x='defense', y='sp_defense')
# Out:
# <AxesSubplot:xlabel='defense', ylabel='sp_defense'>

# %% [markdown]
# Als het gewicht van een pokemon hoog is, verwacht ik dat zijn snelheid laag zal zijn. Ik verwacht dat hier een slechte correlatie in te zien is.

# %%
Pokemon.plot(kind='scatter', x='weight_kg', y='speed')
# Out:
# <AxesSubplot:xlabel='weight_kg', ylabel='speed'>
