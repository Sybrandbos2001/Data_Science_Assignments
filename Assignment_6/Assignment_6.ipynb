# %% [markdown]
# ### Portfolio assignment 6
# Perform a univariate analysis on at least 2 columns with categorical data and on at least 2 columns with numerical data in the dataset that you chose in portfolio assignment 4. Commit the Notebook to your portfolio when you're finished.

# %%
import pandas as pd

# %%
Pokemon = pd.read_csv('pokemon.csv', sep=',')

# %%
Pokemon.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
Pokemon['type1'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
CensorRatedFilter = (movieDataSet['movies_censor_rated'] == "R")
MovieDirectorFilter = (movieDataSet['movies_director'] == "Christopher Nolan") 

FilteredList = movieDataSet[CensorRatedFilter & MovieDirectorFilter]

# %%
FilteredList
# Out:
#                movies_name  movies_metascore  movies_ratings movies_time  \
# 206                Dunkirk              94.0             7.9     106 min
# 275                  Tenet              69.0             7.7     150 min
# 376  The Dark Knight Rises              78.0             8.4     164 min
# 385           Interstellar              74.0             8.6     169 min
# 802              Inception              74.0             8.8     148 min
# 918        The Dark Knight              84.0             9.0     152 min
# 956           The Prestige              66.0             8.5     130 min
# 960          Batman Begins              70.0             8.2     140 min
#
#                  movies_genres movies_censor_rated    movies_director  \
# 206     Action, Drama, History               PG-13  Christopher Nolan
# 275             Action, Sci-Fi               PG-13  Christopher Nolan
# 376          Action, Adventure               PG-13  Christopher Nolan
# ...

# %%
MovieRatingFilter = (movieDataSet['movies_ratings'] >= 9.0) 
MovieMetaScoreFilter = (movieDataSet['movies_metascore'] >= 90.0)

FilteredList = movieDataSet[MovieRatingFilter & MovieMetaScoreFilter]

# %%
FilteredList.head()
# Out:
#                 movies_name  movies_metascore  movies_ratings movies_time  \
# 901           The Godfather             100.0             9.2     175 min
# 916  The Godfather: Part II              90.0             9.0     202 min
# 990            12 Angry Men              96.0             9.0      96 min
#
#     movies_genres movies_censor_rated       movies_director  Unnamed: 7  \
# 901  Crime, Drama                   R  Francis Ford Coppola         NaN
# 916  Crime, Drama                   R  Francis Ford Coppola         NaN
# 990  Crime, Drama            Approved          Sidney Lumet         NaN
#
#     movies_votes movies_gross
# 901    1,597,581     $134.97M
# 916    1,115,932      $57.30M
# 990      680,611       $4.36M
